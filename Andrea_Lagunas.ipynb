# %% [markdown]
# <a href="https://colab.research.google.com/github/OscarIraira23/MachineLearning/blob/main/Andrea_Lagunas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('names.csv')
print(df)
# Out:
#    first_name       last_name                           email
# 0        John             Doe         john-doe@bogusemail.com
# 1        Mary  Smith-Robinson       maryjacobs@bogusemail.com
# 2        Dave           Smith        davesmith@bogusemail.com
# 3        Jane          Stuart       janestuart@bogusemail.com
# 4         Tom          Wright        tomwright@bogusemail.com
# 5       Steve        Robinson    steverobinson@bogusemail.com
# 6      Nicole          Jacobs     nicolejacobs@bogusemail.com
# 7        Jane          Wright       janewright@bogusemail.com
# 8        Jane             Doe          janedoe@bogusemail.com
# 9        Kurt          Wright       kurtwright@bogusemail.com
# 10       Kurt        Robinson     kurtrobinson@bogusemail.com
# 11       Jane         Jenkins      janejenkins@bogusemail.com
# 12       Neil        Robinson     neilrobinson@bogusemail.com
# 13        Tom       Patterson     tompatterson@bogusemail.com
# ...

# %%
df.columns
# Out:
# Index(['first_name', 'last_name', 'email'], dtype='object')

# %%
df.shape
# Out:
# (44, 3)

# %%
x=np.random.randint(low=10, high=60, size=44)
df.insert(loc=3, column = 'Edades',value=x)
#df.drop(['Edad'], axis=3)

# %%
print(df)
# Out:
#    first_name       last_name                           email  Edades
# 0        John             Doe         john-doe@bogusemail.com      19
# 1        Mary  Smith-Robinson       maryjacobs@bogusemail.com      43
# 2        Dave           Smith        davesmith@bogusemail.com      47
# 3        Jane          Stuart       janestuart@bogusemail.com      24
# 4         Tom          Wright        tomwright@bogusemail.com      52
# 5       Steve        Robinson    steverobinson@bogusemail.com      16
# 6      Nicole          Jacobs     nicolejacobs@bogusemail.com      13
# 7        Jane          Wright       janewright@bogusemail.com      57
# 8        Jane             Doe          janedoe@bogusemail.com      48
# 9        Kurt          Wright       kurtwright@bogusemail.com      44
# 10       Kurt        Robinson     kurtrobinson@bogusemail.com      23
# 11       Jane         Jenkins      janejenkins@bogusemail.com      34
# ...

# %%
y=np.random.randint(low=100, high=200, size=44)
df.insert(loc=4, column = 'Alturas',value=y)

# %%
print(df)
# Out:
#    first_name       last_name                           email  Edades  Alturas
# 0        John             Doe         john-doe@bogusemail.com      19      109
# 1        Mary  Smith-Robinson       maryjacobs@bogusemail.com      43      115
# 2        Dave           Smith        davesmith@bogusemail.com      47      114
# 3        Jane          Stuart       janestuart@bogusemail.com      24      129
# 4         Tom          Wright        tomwright@bogusemail.com      52      197
# 5       Steve        Robinson    steverobinson@bogusemail.com      16      106
# 6      Nicole          Jacobs     nicolejacobs@bogusemail.com      13      102
# 7        Jane          Wright       janewright@bogusemail.com      57      138
# 8        Jane             Doe          janedoe@bogusemail.com      48      137
# 9        Kurt          Wright       kurtwright@bogusemail.com      44      117
# 10       Kurt        Robinson     kurtrobinson@bogusemail.com      23      174
# ...

# %%
df.sort_values(by='last_name')
# Out:
#    first_name       last_name                           email  Edades  Alturas
# 43     Travis          Arnold     travisarnold@bogusemail.com      37      127
# 41     Travis          Arnold     travisarnold@bogusemail.com      23      144
# 32      Corey           Davis       coreydavis@bogusemail.com      52      115
# 25       Dave           Davis        davedavis@bogusemail.com      19      192
# 18       Jane             Doe          janedoe@bogusemail.com      52      128
# 8        Jane             Doe          janedoe@bogusemail.com      48      137
# 0        John             Doe         john-doe@bogusemail.com      19      109
# 35       John          Jacobs       johnjacobs@bogusemail.com      51      148
# 6      Nicole          Jacobs     nicolejacobs@bogusemail.com      13      102
# 33      Steve          Jacobs      stevejacobs@bogusemail.com      51      156
# 22       Kurt       Jefferson    kurtjefferson@bogusemail.com      37      122
# ...

# %%
#d=df['last_name'].str.startswith('D', na=False)
df_d=df[df['last_name'].str.startswith('D')]
print(df_d)
# Out:
#    first_name last_name                      email  Edades  Alturas
# 0        John       Doe    john-doe@bogusemail.com      19      109
# 8        Jane       Doe     janedoe@bogusemail.com      48      137
# 18       Jane       Doe     janedoe@bogusemail.com      52      128
# 25       Dave     Davis   davedavis@bogusemail.com      19      192
# 32      Corey     Davis  coreydavis@bogusemail.com      52      115

# %%
print(f'Existen {len(df_d.index)} personas que el inicial de su apellido es con D')
# Out:
# Existen 5 personas que el inicial de su apellido es con D

# %%
df_m=df[df['last_name'].str.startswith('M')]
print(df_m)
# Out:
# Empty DataFrame
# Columns: [first_name, last_name, email, Edades, Alturas]
# Index: []

# %%
print(f'{len(df_m.index)}')
# Out:
# 0

# %%
df.shape
# Out:
# (44, 5)

# %%
df_d.describe()
# Out:
#           Edades     Alturas
# count   5.000000    5.000000
# mean   38.000000  136.200000
# std    17.421251   33.056013
# min    19.000000  109.000000
# 25%    19.000000  115.000000
# 50%    48.000000  128.000000
# 75%    52.000000  137.000000
# max    52.000000  192.000000
